# %% [markdown]
# # AD/MCI/Control classification (GSE63061) — Colab runner
#
# Edit the repo URL in the next cell to your own GitHub repo, then Runtime > Run all.

# %%
REPO_URL = "https://github.com/YOUR_USERNAME/YOUR_REPO.git"  # <-- change this

import os
repo_name = REPO_URL.rstrip("/").rstrip(".git").split("/")[-1]
if not os.path.exists(repo_name):
    # !git clone {REPO_URL}
# %cd {repo_name}
# !pip install -q -r requirements.txt

# %%
# Colab has full internet access, so this downloads GSE63061 directly from NCBI
# (no need to upload the data file manually).
# !python pipeline.py GSE63061

# %%
from IPython.display import Image
Image("output/shap_summary.png")
